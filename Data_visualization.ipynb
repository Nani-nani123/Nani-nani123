# %% [markdown]
# <a href="https://colab.research.google.com/github/Nani-nani123/python-datavisualization/blob/main/Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/arib168/data/main/50_Startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df['State'].value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
State = df.State.unique()
State
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df['State'].value_counts().plot(kind='bar')

# %%
df["State"].value_counts().plot(kind ='pie',autopct = '%1.2f%%')
plt.legend()

# %%
import matplotlib as plt

# %%
import numpy as np

# %%
import seaborn as sns
sns.scatterplot(x='State',y='Profit',data = df, hue = 'State', s = 100, alpha = 0.7)

# %%
import matplotlib.pyplot as plt
sns.distplot(df['Profit'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# at density nearly 1 the highest profit is 100000

# %%
sns.catplot(x='State',y = 'Profit',data = df,kind ='box')

# %%
df["State"].value_counts().plot(kind ='bar')

# %%
 Start_ups=df.select_dtypes(include=['int64','float64'])

# %%
Start_ups
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
Start_ups. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   Profit           50 non-null     float64
# dtypes: float64(4)
# memory usage: 1.7 KB

# %%
x = Start_ups.iloc[:,0:3].values

# %%
y = Start_ups.iloc[:,3].values

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([104858.68792624, 132180.42376363, 133322.11933423,  72113.62933704,
#        179083.55561998, 114843.75907009,  65955.16143209,  98683.96747911,
#        114456.08522159, 168405.59509517,  96182.70251536,  87655.37645653,
#        110908.05435256])

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
plt.figure(figsize = (12,4), dpi = 200)
sns.scatterplot(x ='Administration', y ='Marketing Spend', data=df)

# %%
plt.figure(figsize = (12,4), dpi = 200)
sns.scatterplot(x ='Administration', y ='Marketing Spend', data=df, hue = 'State',palette = 'Dark2')

# %%
plt.figure(figsize = (12,4), dpi = 200)
sns.scatterplot(x ='Administration', y ='Marketing Spend', data=df, size ='Marketing Spend')

# %%
plt.figure(figsize = (12,4), dpi = 200)
sns.scatterplot(x ='State', y ='Profit', data=df)

# %%
sns.relplot(data = df, x = 'Profit',y = 'Marketing Spend',hue ='Administration',col ='State',col_wrap=2)

# %%
sns.stripplot(x='R&D Spend',y='Administration',data=df)

# %%
sns.jointplot(x="R&D Spend",y="Profit", data = df,kind = 'kde',color='green')
sns.jointplot(x="R&D Spend",y="Profit", data = df,kind = 'hist',color='orange')
sns.jointplot(x="R&D Spend",y="Profit", data = df,kind = 'hex',color='purple')
